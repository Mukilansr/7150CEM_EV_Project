# %%
import pandas as pd
import numpy as np
import json
with open(r'acn.json', 'r') as jf:
    ev = json.load(jf)
       
# Flatten data
df = pd.json_normalize(ev, record_path =['_items'])
df.head()
# Out:
#                         _id clusterID                 connectionTime  \
# 0  5bc90cb9f9af8b0d7fe77cd2      0039  Wed, 25 Apr 2018 11:08:04 GMT
# 1  5bc90cb9f9af8b0d7fe77cd3      0039  Wed, 25 Apr 2018 13:45:10 GMT
# 2  5bc90cb9f9af8b0d7fe77cd4      0039  Wed, 25 Apr 2018 13:45:50 GMT
# 3  5bc90cb9f9af8b0d7fe77cd5      0039  Wed, 25 Apr 2018 14:37:06 GMT
# 4  5bc90cb9f9af8b0d7fe77cd6      0039  Wed, 25 Apr 2018 14:40:34 GMT
#
#                   disconnectTime               doneChargingTime  kWhDelivered  \
# 0  Wed, 25 Apr 2018 13:20:10 GMT  Wed, 25 Apr 2018 13:21:10 GMT         7.932
# 1  Thu, 26 Apr 2018 00:56:16 GMT  Wed, 25 Apr 2018 16:44:15 GMT        10.013
# 2  Wed, 25 Apr 2018 23:04:45 GMT  Wed, 25 Apr 2018 14:51:44 GMT         5.257
# 3  Wed, 25 Apr 2018 23:55:34 GMT  Wed, 25 Apr 2018 16:05:22 GMT         5.177
# 4  Wed, 25 Apr 2018 23:03:12 GMT  Wed, 25 Apr 2018 17:40:30 GMT        10.119
#
#                                 sessionID siteID spaceID    stationID  \
# ...

# %%
df_pre=df

# %%
df_pre
# Out:
#                             _id clusterID                 connectionTime  \
# 0      5bc90cb9f9af8b0d7fe77cd2      0039  Wed, 25 Apr 2018 11:08:04 GMT
# 1      5bc90cb9f9af8b0d7fe77cd3      0039  Wed, 25 Apr 2018 13:45:10 GMT
# 2      5bc90cb9f9af8b0d7fe77cd4      0039  Wed, 25 Apr 2018 13:45:50 GMT
# 3      5bc90cb9f9af8b0d7fe77cd5      0039  Wed, 25 Apr 2018 14:37:06 GMT
# 4      5bc90cb9f9af8b0d7fe77cd6      0039  Wed, 25 Apr 2018 14:40:34 GMT
# ...                         ...       ...                            ...
# 31419  61550519f9af8b76960e169a      0039  Mon, 13 Sep 2021 21:12:53 GMT
# 31420  61550519f9af8b76960e169b      0039  Mon, 13 Sep 2021 21:17:04 GMT
# 31421  61550519f9af8b76960e169c      0039  Mon, 13 Sep 2021 22:33:07 GMT
# 31422  61550519f9af8b76960e169d      0039  Mon, 13 Sep 2021 23:11:12 GMT
# 31423  61550519f9af8b76960e169e      0039  Tue, 14 Sep 2021 01:52:37 GMT
#
#                       disconnectTime               doneChargingTime  \
# ...

# %%
def date_conversion(col):     
    date_connection_time = pd.to_datetime(df_pre[col], format="%a, %d %b %Y %X %Z")
    date_format_connect = date_connection_time.dt.tz_localize(None)
    connect_date = date_format_connect.dt.date
    df_pre[col] = connect_date
    df_pre[col]=df_pre[col].astype('datetime64[ns]')
#     return df_pre[col]

# %%
df_pre['doneChargingTime'].fillna(df_pre['disconnectTime'],inplace=True)

# %%
date_conversion('connectionTime')
date_conversion('disconnectTime')
date_conversion('doneChargingTime')

# %%
df_pre
# Out:
#                             _id clusterID connectionTime disconnectTime  \
# 0      5bc90cb9f9af8b0d7fe77cd2      0039     2018-04-25     2018-04-25
# 1      5bc90cb9f9af8b0d7fe77cd3      0039     2018-04-25     2018-04-26
# 2      5bc90cb9f9af8b0d7fe77cd4      0039     2018-04-25     2018-04-25
# 3      5bc90cb9f9af8b0d7fe77cd5      0039     2018-04-25     2018-04-25
# 4      5bc90cb9f9af8b0d7fe77cd6      0039     2018-04-25     2018-04-25
# ...                         ...       ...            ...            ...
# 31419  61550519f9af8b76960e169a      0039     2021-09-13     2021-09-14
# 31420  61550519f9af8b76960e169b      0039     2021-09-13     2021-09-14
# 31421  61550519f9af8b76960e169c      0039     2021-09-13     2021-09-13
# 31422  61550519f9af8b76960e169d      0039     2021-09-13     2021-09-14
# 31423  61550519f9af8b76960e169e      0039     2021-09-14     2021-09-14
#
#       doneChargingTime  kWhDelivered                                sessionID  \
# ...

# %%
df_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31424 entries, 0 to 31423
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               31424 non-null  object
#  1   clusterID         31424 non-null  object
#  2   connectionTime    31424 non-null  datetime64[ns]
#  3   disconnectTime    31424 non-null  datetime64[ns]
#  4   doneChargingTime  31424 non-null  datetime64[ns]
#  5   kWhDelivered      31424 non-null  float64
#  6   sessionID         31424 non-null  object
#  7   siteID            31424 non-null  object
#  8   spaceID           31424 non-null  object
#  9   stationID         31424 non-null  object
#  10  timezone          31424 non-null  object
#  11  userID            16388 non-null  object
#  12  userInputs        16388 non-null  object
# dtypes: datetime64[ns](3), float64(1), object(9)
# memory usage: 3.1+ MB

# %%
def ev_univ(input_col,pred_col):
    ev_univ = df_pre[[input_col,pred_col]]
    ev_univ_agg = ev_univ.groupby([input_col]).agg({pred_col:np.sum})
    return ev_univ_agg

# %%
uni_1 = ev_univ('doneChargingTime','kWhDelivered')
uni_2 = ev_univ('connectionTime','kWhDelivered')
uni_3 = ev_univ('disconnectTime','kWhDelivered')

# %%
uni_1
# Out:
#                   kWhDelivered
# doneChargingTime
# 2018-04-25             265.036
# 2018-04-26             379.263
# 2018-04-27             445.707
# 2018-04-28             434.477
# 2018-04-29             324.008
# ...                        ...
# 2021-09-10             434.621
# 2021-09-11             227.341
# 2021-09-12             182.061
# 2021-09-13             446.156
# 2021-09-14             174.830
#
# [1078 rows x 1 columns]

# %%
uni_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1078 entries, 2018-04-25 to 2021-09-14
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   kWhDelivered  1078 non-null   float64
# dtypes: float64(1)
# memory usage: 16.8 KB

# %%
uni_2=uni_1.reset_index()

# %%
analy_post_pand_weekend=uni_2[uni_2['doneChargingTime']>'2020-09-01']

# %%
analy_post_pand_weekend
# Out:
#      doneChargingTime  kWhDelivered
# 777        2020-11-18         2.237
# 778        2020-11-19        95.052
# 779        2020-11-20        46.461
# 780        2020-11-21        18.853
# 781        2020-11-22        25.530
# ...               ...           ...
# 1073       2021-09-10       434.621
# 1074       2021-09-11       227.341
# 1075       2021-09-12       182.061
# 1076       2021-09-13       446.156
# 1077       2021-09-14       174.830
#
# [301 rows x 2 columns]

# %%
uni_3 = analy_post_pand_weekend.set_index('doneChargingTime')

# %%
uni_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 301 entries, 2020-11-18 to 2021-09-14
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   kWhDelivered  301 non-null    float64
# dtypes: float64(1)
# memory usage: 4.7 KB

# %%
uni_3.index.freq = 'D'

# %%
uni_3.index
# Out:
# DatetimeIndex(['2020-11-18', '2020-11-19', '2020-11-20', '2020-11-21',
#                '2020-11-22', '2020-11-23', '2020-11-24', '2020-11-25',
#                '2020-11-26', '2020-11-27',
#                ...
#                '2021-09-05', '2021-09-06', '2021-09-07', '2021-09-08',
#                '2021-09-09', '2021-09-10', '2021-09-11', '2021-09-12',
#                '2021-09-13', '2021-09-14'],
#               dtype='datetime64[ns]', name='doneChargingTime', length=301, freq='D')

# %%
uni_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 301 entries, 2020-11-18 to 2021-09-14
# Freq: D
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   kWhDelivered  301 non-null    float64
# dtypes: float64(1)
# memory usage: 4.7 KB

# %%
uni_3
# Out:
#                   kWhDelivered
# doneChargingTime
# 2020-11-18               2.237
# 2020-11-19              95.052
# 2020-11-20              46.461
# 2020-11-21              18.853
# 2020-11-22              25.530
# ...                        ...
# 2021-09-10             434.621
# 2021-09-11             227.341
# 2021-09-12             182.061
# 2021-09-13             446.156
# 2021-09-14             174.830
#
# [301 rows x 1 columns]

# %%
from statsmodels.tsa.stattools import adfuller

def adf_test(series,title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(),autolag='AIC') # .dropna() handles differenced data
    
    labels = ['ADF test statistic','p-value','# lags used','# observations']
    out = pd.Series(result[0:4],index=labels)

    for key,val in result[4].items():
        out[f'critical value ({key})']=val
        
    print(out.to_string())          # .to_string() removes the line "dtype: float64"
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")

# %%
adf_test(uni_3['kWhDelivered'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic       -1.220203
# p-value                   0.664845
# # lags used               7.000000
# # observations          293.000000
# critical value (1%)      -3.452867
# critical value (5%)      -2.871455
# critical value (10%)     -2.572053
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %%
uni_3['kWhDelivered_diff'] = uni_3['kWhDelivered'].diff().dropna()
uni_3['kWhDelivered_diff'].diff().dropna().plot()

# %%
uni_3
# Out:
#                   kWhDelivered  kWhDelivered_diff
# doneChargingTime
# 2020-11-18               2.237                NaN
# 2020-11-19              95.052             92.815
# 2020-11-20              46.461            -48.591
# 2020-11-21              18.853            -27.608
# 2020-11-22              25.530              6.677
# ...                        ...                ...
# 2021-09-10             434.621            142.686
# 2021-09-11             227.341           -207.280
# 2021-09-12             182.061            -45.280
# 2021-09-13             446.156            264.095
# 2021-09-14             174.830           -271.326
#
# [301 rows x 2 columns]

# %%
uni_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 301 entries, 2020-11-18 to 2021-09-14
# Freq: D
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   kWhDelivered       301 non-null    float64
#  1   kWhDelivered_diff  300 non-null    float64
# dtypes: float64(2)
# memory usage: 7.1 KB

# %%
uni_4 = uni_3

# %%
uni_5 = uni_4.dropna()

# %%
uni_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 300 entries, 2020-11-19 to 2021-09-14
# Freq: D
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   kWhDelivered       300 non-null    float64
#  1   kWhDelivered_diff  300 non-null    float64
# dtypes: float64(2)
# memory usage: 7.0 KB

# %%
adf_test(uni_5['kWhDelivered_diff'])
# Out:
# Augmented Dickey-Fuller Test:
# ADF test statistic     -1.139496e+01
# p-value                 7.899647e-21
# # lags used             6.000000e+00
# # observations          2.930000e+02
# critical value (1%)    -3.452867e+00
# critical value (5%)    -2.871455e+00
# critical value (10%)   -2.572053e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
from pmdarima import auto_arima
auto_arima(uni_5['kWhDelivered_diff'],seasonal=True,m=7).summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                                 y   No. Observations:                  300
# Model:             SARIMAX(0, 0, 1)x(1, 0, 1, 7)   Log Likelihood               -1633.951
# Date:                           Wed, 22 Jun 2022   AIC                           3275.902
# Time:                                   13:19:40   BIC                           3290.717
# Sample:                                        0   HQIC                          3281.831
#                                            - 300
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8525      0.029    -28.947      0.000      -0.910      -0.795
# ar.S.L7        0.9325      0.082     11.374      0.000       0.772       1.093
# ...

# %%
uni_5
# Out:
#                   kWhDelivered  kWhDelivered_diff
# doneChargingTime
# 2020-11-19              95.052             92.815
# 2020-11-20              46.461            -48.591
# 2020-11-21              18.853            -27.608
# 2020-11-22              25.530              6.677
# 2020-11-23              68.985             43.455
# ...                        ...                ...
# 2021-09-10             434.621            142.686
# 2021-09-11             227.341           -207.280
# 2021-09-12             182.061            -45.280
# 2021-09-13             446.156            264.095
# 2021-09-14             174.830           -271.326
#
# [300 rows x 2 columns]

# %%
train = uni_5.iloc[:269]
train
# Out:
#                   kWhDelivered  kWhDelivered_diff
# doneChargingTime
# 2020-11-19           95.052000          92.815000
# 2020-11-20           46.461000         -48.591000
# 2020-11-21           18.853000         -27.608000
# 2020-11-22           25.530000           6.677000
# 2020-11-23           68.985000          43.455000
# ...                        ...                ...
# 2021-08-10          211.641477          28.175477
# 2021-08-11          246.161619          34.520142
# 2021-08-12          349.947000         103.785381
# 2021-08-13          198.747000        -151.200000
# 2021-08-14          110.355000         -88.392000
#
# [269 rows x 2 columns]

# %%
test = uni_5.iloc[269:]
test
# Out:
#                   kWhDelivered  kWhDelivered_diff
# doneChargingTime
# 2021-08-15          285.470000         175.115000
# 2021-08-16          317.249000          31.779000
# 2021-08-17          222.572000         -94.677000
# 2021-08-18          184.955000         -37.617000
# 2021-08-19          349.104773         164.149773
# 2021-08-20          209.147000        -139.957773
# 2021-08-21          199.961000          -9.186000
# 2021-08-22          154.342000         -45.619000
# 2021-08-23          152.817719          -1.524281
# 2021-08-24          327.554000         174.736281
# 2021-08-25          247.622000         -79.932000
# 2021-08-26          212.727000         -34.895000
# 2021-08-27          263.036000          50.309000
# 2021-08-28          305.007000          41.971000
# 2021-08-29          216.259000         -88.748000
# 2021-08-30          309.303000          93.044000
# 2021-08-31          373.424000          64.121000
# ...

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model_post = SARIMAX(train['kWhDelivered_diff'],order=(0,0,1),seasonal_order=(0, 0, 1, 7))
results_post = model_post.fit()
results_post.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                 kWhDelivered_diff   No. Observations:                  269
# Model:             SARIMAX(0, 0, 1)x(0, 0, 1, 7)   Log Likelihood               -1448.936
# Date:                           Wed, 22 Jun 2022   AIC                           2903.872
# Time:                                   13:21:05   BIC                           2914.656
# Sample:                               11-19-2020   HQIC                          2908.202
#                                     - 08-14-2021
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8422      0.031    -27.513      0.000      -0.902      -0.782
# ma.S.L7        0.1543      0.055      2.782      0.005       0.046       0.263
# ...

# %%
# Obtain predicted values
start_post=len(train)
end_post=len(train)+len(test)-1
predictions_post = results_post.predict(start=start_post, end=end_post, dynamic=False, typ='levels').rename('SARIMA(1,0,1) Predictions')

# %%
# HERE'S A TRICK TO ADD COMMAS TO Y-AXIS TICK VALUES
import matplotlib.ticker as ticker
formatter = ticker.StrMethodFormatter('{x:,.0f}')
# Plot predictions against known values
title = 'EV prediction'
ylabel='KWh Delivered'
xlabel='' # we don't really need a label here

ax = test['kWhDelivered_diff'].plot(legend=True,figsize=(12,6),title=title)
predictions_post.plot(legend=True)
ax.autoscale(axis='x',tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
ax.yaxis.set_major_formatter(formatter);

# %%
uni_5.describe()
# Out:
#        kWhDelivered  kWhDelivered_diff
# count    300.000000         300.000000
# mean     135.160102           0.575310
# std       82.316576          73.858415
# min        5.993000        -271.326000
# 25%       72.093500         -43.171000
# 50%      119.258000           3.103000
# 75%      189.211500          45.877250
# max      446.156000         264.095000

# %%
from sklearn.metrics import mean_squared_error

error = mean_squared_error(test['kWhDelivered_diff'], predictions_post)
print(f'SARIMAX(1,0,1) MSE Error: {error}')
# Out:
# SARIMAX(1,0,1) MSE Error: 11770.097569298288
